# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi611/50-Days-Coding-Challenge/blob/main/Day%2033/Day_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Level 1: Placement Thinking
#
# 1. Number Guessing Game

# %%
secret = 7

while True:
    guess = int(input("Enter your guess: "))

    if guess < secret:
        print("Too Low")
    elif guess > secret:
        print("Too High")
    else:
        print("You Won!")
        break
# Out:
# Enter your guess: 5
# Too Low
# Enter your guess: 8
# Too High
# Enter your guess: 7
# You Won!

# %% [markdown]
# 2. Reverse a Number

# %%
num = int(input("Enter a number: "))
rev = 0

while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num = num // 10

print("Reversed Number:", rev)
# Out:
# Enter a number: 56
# Reversed Number: 65

# %% [markdown]
# 3. Count Digits in Number

# %%
num = int(input("Enter a number: "))
count = 0

while num > 0:
    num = num // 10
    count += 1

print("Number of digits:", count)
# Out:
# Enter a number: 123
# Number of digits: 3

# %% [markdown]
# Level 2: Real-World Scenario (Data Analyst Thinking)
#
# 4. Sales Threshold Checker

# %%
sales = [1200, 800, 1500, 400, 2000]
count = 0

print("Sales greater than 1000:")

for s in sales:
    if s > 1000:
        print(s)
        count += 1

print("Count:", count)
# Out:
# Sales greater than 1000:
# 1200
# 1500
# 2000
# Count: 3

# %% [markdown]
# 5. Continuous Data Entry System

# %%
total = 0

while True:
    num = int(input("Enter number (0 to stop): "))

    if num == 0:
        break

    total += num

print("Total sum:", total)
# Out:
# Enter number (0 to stop): 5
# Enter number (0 to stop): 1
# Enter number (0 to stop): 8
# Enter number (0 to stop): 0
# Total sum: 14
