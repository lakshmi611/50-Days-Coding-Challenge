# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi611/50-Days-Coding-Challenge/blob/main/Day%2024/Day%2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rides = (
    (101, "Ravi", "Bangalore", 250, 4.5),
    (102, "Anjali", "Hyderabad", 180, 4.2),
    (103, "Kiran", "Bangalore", 300, 4.8),
    (104, "Meena", "Chennai", 220, 4.0),
    (105, "Arjun", "Bangalore", 150, 3.9)
)

# %%
total_rides = len(rides)
print("Total Rides:", total_rides)
# Out:
# Total Rides: 5

# %%
bangalore_rides = [ride for ride in rides if ride[2] == "Bangalore"]
print("Bangalore Rides:", bangalore_rides)
# Out:
# Bangalore Rides: [(101, 'Ravi', 'Bangalore', 250, 4.5), (103, 'Kiran', 'Bangalore', 300, 4.8), (105, 'Arjun', 'Bangalore', 150, 3.9)]

# %%
total_revenue = sum(ride[3] for ride in rides if ride[2] == "Bangalore")
print("Total Revenue (Bangalore):", total_revenue)
# Out:
# Total Revenue (Bangalore): 700

# %%
highest_rated = max(rides, key=lambda x: x[4])
print("Highest Rated Driver:", highest_rated)
# Out:
# Highest Rated Driver: (103, 'Kiran', 'Bangalore', 300, 4.8)

# %%
city_ratings = {}

for ride in rides:
    city = ride[2]
    rating = ride[4]

    if city not in city_ratings:
        city_ratings[city] = []

    city_ratings[city].append(rating)

# Calculate averages
avg_ratings = {city: round(sum(ratings)/len(ratings), 1)
               for city, ratings in city_ratings.items()}

print("Average Rating per City:", avg_ratings)
# Out:
# Average Rating per City: {'Bangalore': 4.4, 'Hyderabad': 4.2, 'Chennai': 4.0}
