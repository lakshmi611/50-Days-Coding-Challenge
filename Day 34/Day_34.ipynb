# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi611/50-Days-Coding-Challenge/blob/main/Day%2034/Day_34.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Remove Duplicates & Preserve Order

# %%
ids = [101, 102, 101, 103, 102, 104]

unique_ids = []
for i in ids:
    if i not in unique_ids:
        unique_ids.append(i)

print(unique_ids)
# Out:
# [101, 102, 103, 104]

# %% [markdown]
# 2. Frequency Counter (Real-time Analytics)

# %%
products = ["apple", "banana", "apple", "orange", "banana", "apple"]

freq = {}

for item in products:
    freq[item] = freq.get(item, 0) + 1

print(freq)
# Out:
# {'apple': 3, 'banana': 2, 'orange': 1}

# %% [markdown]
# 3. Find Top Scorer

# %%
marks = {"A": 85, "B": 92, "C": 88}

topper = max(marks, key=marks.get)

print(topper)
# Out:
# B

# %% [markdown]
# 4. Common Elements in Two Lists

# %%
skills1 = ["Python", "SQL", "Excel"]
skills2 = ["SQL", "Power BI", "Python"]

common = list(set(skills1).intersection(set(skills2)))

print(common)
# Out:
# ['Python', 'SQL']

# %% [markdown]
# 5. Sort Dictionary by Values

# %%
prices = {"apple": 50, "banana": 20, "orange": 30}

sorted_prices = sorted(prices.items(), key=lambda x: x[1])

print(sorted_prices)
# Out:
# [('banana', 20), ('orange', 30), ('apple', 50)]
