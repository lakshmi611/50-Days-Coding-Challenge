# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi611/50-Days-Coding-Challenge/blob/main/Day%2027/Day_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
trips = (
    (101, "Bangalore", 12.5, 250),
    (102, "Hyderabad", 8.0, 180),
    (103, "Bangalore", 15.2, 300),
    (104, "Chennai", 5.5, 120),
    (105, "Bangalore", 7.8, 200)
)

# %%
total_trips = len(trips)
print("Total Trips:", total_trips)
# Out:
# Total Trips: 5

# %%
bangalore_trips = sum(1 for trip in trips if trip[1] == "Bangalore")
print("Trips from Bangalore:", bangalore_trips)
# Out:
# Trips from Bangalore: 3

# %%
total_revenue = sum(trip[3] for trip in trips)
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 1050

# %%
print("High Distance Trips (>10 km):")
for trip in trips:
    if trip[2] > 10:
        print(trip)
# Out:
# High Distance Trips (>10 km):
# (101, 'Bangalore', 12.5, 250)
# (103, 'Bangalore', 15.2, 300)

# %%
highest_fare_trip = max(trips, key=lambda trip: trip[3])
print("Highest Fare Trip:", highest_fare_trip)
# Out:
# Highest Fare Trip: (103, 'Bangalore', 15.2, 300)

# %%
bangalore_fares = [trip[3] for trip in trips if trip[1] == "Bangalore"]
avg_fare = sum(bangalore_fares) / len(bangalore_fares)

print("Average Fare (Bangalore):", avg_fare)
# Out:
# Average Fare (Bangalore): 250.0
