# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmi611/50-Days-Coding-Challenge/blob/main/Day%2025/Day_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ("sunitha", "RAVI", "aNu")

formatted_students = tuple(name.capitalize() for name in students)

print("Formatted Names:", formatted_students)
# Out:
# Formatted Names: ('Sunitha', 'Ravi', 'Anu')

# %%
subjects = ("Math", "Science", "English", "Math", "Science")

total_subjects = len(subjects)
unique_subjects = set(subjects)

print("Total Subjects:", total_subjects)
print("Unique Subjects:", unique_subjects)
# Out:
# Total Subjects: 5
# Unique Subjects: {'English', 'Science', 'Math'}

# %%
feedback = (" good course ", " excellent ", "average ")

cleaned_feedback = tuple(f.strip() for f in feedback)

print("Cleaned Feedback:", cleaned_feedback)
# Out:
# Cleaned Feedback: ('good course', 'excellent', 'average')

# %%
names = ("Anu", "Ravi", "John")
courses = ("Python", "SQL", "Power BI")

combined = tuple(name + "-" + course for name, course in zip(names, courses))

print("Combined Tuple:", combined)
# Out:
# Combined Tuple: ('Anu-Python', 'Ravi-SQL', 'John-Power BI')

# %%
emails = ("anu@gmail.com", "ravi@yahoo.com", "john@edu.com")

domains = tuple(email.split("@")[1] for email in emails)

print("Email Domains:", domains)
# Out:
# Email Domains: ('gmail.com', 'yahoo.com', 'edu.com')
